# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("CKD.csv")
dataset=pd.get_dummies(dataset).astype(int)

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
print(dataset.columns)
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_a', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_abnormal',
#        'rbc_normal', 'pc_abnormal', 'pc_normal', 'pcc_notpresent',
#        'pcc_present', 'ba_notpresent', 'ba_present', 'htn_no', 'htn_yes',
#        'dm_no', 'dm_yes', 'cad_no', 'cad_yes', 'appet_poor', 'appet_yes',
#        'pe_poor', 'pe_yes', 'ane_no', 'ane_yes', 'classification_no',
#        'classification_yes'],
#       dtype='object')

# %%
independent=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_a', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_abnormal',
       'rbc_normal', 'pc_abnormal', 'pc_normal', 'pcc_notpresent',
       'pcc_present', 'ba_notpresent', 'ba_present', 'htn_no', 'htn_yes',
       'dm_no', 'dm_yes', 'cad_no', 'cad_yes', 'appet_poor', 'appet_yes',
       'pe_poor', 'pe_yes', 'ane_no', 'ane_yes']]

# %%
independent=dataset[['bgr', 'bu', 'sc', 'pcv', 'wc']]

# %%
dependent=dataset[['classification_yes']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy')
classifier.fit(X_train,Y_train)
# Out:
# C:\Users\SAN\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
# Out:
# [[43  2]
#  [ 4 71]]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(Y_test, y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        45
#            1       0.97      0.95      0.96        75
#
#     accuracy                           0.95       120
#    macro avg       0.94      0.95      0.95       120
# weighted avg       0.95      0.95      0.95       120

# %%
selector = SelectKBest(score_func=chi2, k=10)
new_data = selector.fit_transform(independent, dependent)
# Out:
# C:\Users\SAN\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:783: UserWarning: k=10 is greater than n_features=5. All the features will be returned.
#   warnings.warn(

# %%
from sklearn.feature_selection import SelectKBest, chi2
selector = SelectKBest(score_func=chi2, k=5)
X_selected = selector.fit_transform(independent, dependent)
selected_features = independent.columns[selector.get_support()]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['bgr', 'bu', 'sc', 'pcv', 'wc'], dtype='object')

# %%
classifier.predict([[148,57,3,38,8408]])
# Out:
# C:\Users\SAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
independent=dataset[['bgr', 'bu', 'sc', 'pcv', 'wc']]
